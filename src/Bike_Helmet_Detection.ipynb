# %% [markdown]
# # **Check Graphics Card is running or not**

# %%
# !nvidia-smi
# Out:
# Wed Nov  5 19:15:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # **Install ultralytics**

# %%
# !pip install ultralytics

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**Start training of YOLO with custom dataset italicized text**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data= ../content/drive/MyDrive/DATASET/bikehelmet/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/args.yaml (deflated 52%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train3/ (stored 0%)
#   adding: content/runs/detect/train3/train_batch0.jpg (deflated 2%)
#   adding: content/runs/detect/train3/BoxF1_curve.png (deflated 13%)
#   adding: content/runs/detect/train3/train_batch1.jpg (deflated 2%)
#   adding: content/runs/detect/train3/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train3/confusion_matrix_normalized.png (deflated 27%)
#   adding: content/runs/detect/train3/args.yaml (deflated 52%)
#   adding: content/runs/detect/train3/train_batch2.jpg (deflated 1%)
# ...

# %%
from google.colab import files
files.download("/content/runs.zip")
